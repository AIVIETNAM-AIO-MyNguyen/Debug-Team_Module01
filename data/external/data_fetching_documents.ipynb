# %%
import sys
import os
from dotenv import load_dotenv

# Adds the parent directory (project root) to the python path
sys.path.append(os.path.abspath(os.path.join("../..")))
load_dotenv()
# Out:
# True

# %%
import pandas as pd

documents_df = pd.read_parquet('../raw/data/documents.parquet')

# %%
new_df = documents_df[documents_df['source_type'] == 'confluence']

# %%
new_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5189 entries, 0 to 5188
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   doc_id       5189 non-null   object
#  1   source_type  5189 non-null   object
#  2   title        5189 non-null   object
#  3   content      5189 non-null   object
# dtypes: object(4)
# memory usage: 162.3+ KB

# %%
new_df.to_parquet('../raw/confluence_documents.parquet')
