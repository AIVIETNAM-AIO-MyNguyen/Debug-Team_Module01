# %%
import os
from datasets import load_dataset
from dotenv import load_dotenv

# Load Hugging Face Login Token for authenticated streaming access
load_dotenv()

doc_ds = load_dataset(
    "ingalepratap/EnterpriseRAG-Bench", 
    "documents", 
    streaming=True
)

quest_ds = load_dataset(
    "ingalepratap/EnterpriseRAG-Bench", 
    "questions", 
    streaming=True
)

document_stream = doc_ds["test"]
question_stream = quest_ds["test"]

# %%
print("--- Document Sample ---")
for item in document_stream.take(2):
    print(item)

print("\n--- Question Sample ---")
for item in question_stream.take(2):
    print(item)
# Out:
# --- Document Sample ---
