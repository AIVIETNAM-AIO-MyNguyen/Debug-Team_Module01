# %%
import sys
import os
from dotenv import load_dotenv

# Adds the parent directory (project root) to the python path
sys.path.append(os.path.abspath(os.path.join("../..")))
load_dotenv()
# Out:
# True

# %%
import pandas as pd

questions_df = pd.read_parquet('../raw/data/questions.parquet')

# %%
# Recommended method
new_df = questions_df[questions_df['source_types'].apply(lambda x: x == [] or x == ['confluence'])].copy()

# %%
new_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 94 entries, 10 to 499
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   question_id       94 non-null     object
#  1   question_type     94 non-null     object
#  2   source_types      94 non-null     object
#  3   question          94 non-null     object
#  4   expected_doc_ids  94 non-null     object
#  5   gold_answer       94 non-null     object
#  6   answer_facts      94 non-null     object
# dtypes: object(7)
# memory usage: 5.9+ KB

# %%
new_df.to_parquet('../raw/confluence_questions.parquet')
